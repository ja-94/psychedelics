# %%
import numpy as np
import pandas as pd
from one.api import ONE
from psyfun import io
from psyfun.config import *
from psyfun import plots
import matplotlib as pl
from matplotlib import pyplot as plt

one = ONE()

# only run if first-time setup
# Fetching all session, insertion, and spike data
# DAVIDE: for some reason, fetching keeps getting interrupted by the absence of certain files/directories.
#%run -i fetchdata.py -a

# Load session and insertion metadata
df_sessions = pd.read_parquet(paths['sessions'])
df_insertions = pd.read_parquet(paths['insertions'])

# dropping na (PCA_DC)
df_sessions = df_sessions.query('n_tasks >= 2').dropna(subset=['task00_spontaneous_start', 'task01_spontaneous_start'])

# Create a DataFrame with eids (all sessions with a left vid), categorized by experimental group
eids_exp = df_sessions.loc[(df_sessions['raw_video_data/_iblrig_leftCamera.raw.mp4'] == True) & (df_sessions['control_recording'] == False), 'eid']
eids_cont = df_sessions.loc[(df_sessions['raw_video_data/_iblrig_leftCamera.raw.mp4'] == True) & (df_sessions['control_recording'] == True), 'eid']

# %%
import os
import numpy as np
import pandas as pd

def download_video(eid, camera = "left"):
    """
    Downloads raw video data from specific session. Camera parameter can be switched to "body" and "right".
    
    Parameters
    ----------
    eid (str): Experiment/session identifier

    camera (str): Camera orientation identifier (left by default). "body", "right" are other available options.

    Returns
    -------
    video_path: Local path for saved video
    """
    
    if camera == "left":
        video_path = one.load_dataset(eid, f'*leftCamera.raw*', collection='raw_video_data')
    elif camera == "right":
        video_path = one.load_dataset(eid, f'*rightCamera.raw*', collection='raw_video_data')
    elif camera == "body":
        video_path = one.load_dataset(eid, f'*bodyCamera.raw*', collection='raw_video_data')
    else:
         raise ValueError(f"Unknown camera parameter: {camera}")

    return video_path

def get_time_epochs(df_sessions, eid):

    video_data = df_sessions.loc[df_sessions['eid'] == eid]
    
    # epochs
    epoch_pre = [
        ("task00_spontaneous", video_data['task00_spontaneous_start'].values[0], video_data['task00_spontaneous_stop'].values[0]),
        ("task00_rfm", video_data['task00_rfm_start'].values[0], video_data['task00_rfm_stop'].values[0]),
        ("task00_replay", video_data['task00_replay_start'].values[0], video_data['task00_replay_stop'].values[0])
    ]

    epoch_post = [
        ("task01_spontaneous", video_data['task01_spontaneous_start'].values[0], video_data['task01_spontaneous_stop'].values[0]),
        ("task01_rfm", video_data['task01_rfm_start'].values[0], video_data['task01_rfm_stop'].values[0]),
        ("task01_replay", video_data['task01_replay_start'].values[0], video_data['task01_replay_stop'].values[0])
    ]

    return epoch_pre, epoch_post


# will be useful for multi-video analysis at the end
def load_pca_results(eid):
    """
    Imports FaceMap results on motion energy video analysis. Obtains path for .npy file based on eid, loads, and returns the data
    in a dictionary dataframe.

    Parameters
    ----------
        eid (str): Experiment/session identifier.

    Returns
    -------
        dictionary: Loaded PCA results.
        Keys() : (parameters )'filenames', 'save_path', 'Ly', 'Lx', 'sbin', 'fullSVD', 'save_mat', 'Lybin', 'Lxbin', 'sybin', 'sxbin', 'LYbin', 'LXbin',
                 (outputs) 'avgframe', 'avgmotion', 'avgframe_reshape', 'avgmotion_reshape', 'motion', 'motSv', 'movSv', 'motMask', 'movMask', 'motMask_reshape', 'movMask_reshape', 'motSVD', 'movSVD', 
                (unused tracking) 'pupil', 'running', 'blink', 'rois', 'sy', 'sx']
    """
    # Assuming consistent naming
    file_path = os.path.join(one.eid2path(eid), "raw_video_data", "_iblrig_leftCamera.raw_proc.npy")
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"PCA results file not found: {file_path}")
    

    data = np.load(file_path, allow_pickle=True).item()
    return data

# %%
#for eid in eids_cont:
 #   video_path = download_video(eid)
# Out:
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.80G/4.80G [07:47<00:00, 10.3MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.14G/4.14G [06:39<00:00, 10.4MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.39G/4.39G [06:49<00:00, 10.7MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.64G/4.64G [08:20<00:00, 9.26MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.67G/4.67G [07:20<00:00, 10.6MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.05G/4.05G [07:13<00:00, 9.35MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.68G/4.68G [07:56<00:00, 9.82MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 4.31G/4.31G [06:35<00:00, 10.9MB/s]
# (S3) C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw.mp4: 100%|██████████| 3.97G/3.97G [06:24<00:00, 10.3MB/s]

# %%
def expected_path(video_path, start_sec, end_sec):
    """
    Constructs expected path to check if epoch was already processed.
    """
    basename, filename = os.path.split(video_path)
    filename, _ = os.path.splitext(filename)
    epoch_str = f"_start{int(start_sec)}_end{int(end_sec)}"
    expected_save = os.path.join(basename, f"{filename}{epoch_str}_proc.npy")

    return expected_save

# %%
import motionmap
import ibllib.io.video as vidio

results = []  # List to store (eid, epoch, savename)

for eid in eids_cont:
    # epoch timing 
    epoch_pre, epoch_post = get_time_epochs(df_sessions, eid)

    # Get video path
    url = one.eid2path(eid)
    if not os.path.exists(url):
        video_path = download_video(eid)
    
    video_path = os.path.join(url, "raw_video_data", "_iblrig_leftCamera.raw.mp4")
    path = [[video_path]]
    
    meta = vidio.get_video_meta(video_path)
    fps = meta['fps']

    # Run for each pre-epoch
    for epoch_name, start_sec, end_sec in epoch_pre:
        # expected save path
        expected_save = expected_path(video_path, start_sec, end_sec) 
        if os.path.exists(expected_save):
            print(f"Skipping {eid} pre_{epoch_name}: already processed at {expected_save}")
            results.append((eid, f'pre_{epoch_name}', expected_save))
            continue

        print("Running session: ", eid, " - epoch: ", epoch_name)
        savename = motionmap.run(path, sbin=4, start_sec=start_sec, end_sec=end_sec)
        results.append((eid, f'pre_{epoch_name}', savename))

    # Run for each post-epoch
    for epoch_name, start_sec, end_sec in epoch_post:
        expected_save = expected_path(video_path, start_sec, end_sec) 
        if os.path.exists(expected_save):
            print(f"Skipping {eid} post_{epoch_name}: already processed at {expected_save}")
            results.append((eid, f'post_{epoch_name}', expected_save))
            continue

        print("Running session: ", eid, " - epoch: ", epoch_name)
        savename = motionmap.run(path, sbin=4, start_sec=start_sec, end_sec=end_sec)
        results.append((eid, f'post_{epoch_name}', savename))
# Out:
# Skipping c7cf8e25-1e2c-4b03-a5f5-5a049f1cd228 pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping c7cf8e25-1e2c-4b03-a5f5-5a049f1cd228 pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start300_end956_proc.npy
# Skipping c7cf8e25-1e2c-4b03-a5f5-5a049f1cd228 pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start956_end1269_proc.npy
# Skipping c7cf8e25-1e2c-4b03-a5f5-5a049f1cd228 post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start3275_end3575_proc.npy
# Skipping c7cf8e25-1e2c-4b03-a5f5-5a049f1cd228 post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start3575_end4230_proc.npy
# Skipping c7cf8e25-1e2c-4b03-a5f5-5a049f1cd228 post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start4230_end4543_proc.npy
# Skipping 878b86b7-9245-40a3-843e-9ebf0a8251db pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping 878b86b7-9245-40a3-843e-9ebf0a8251db pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start300_end657_proc.npy
# Skipping 878b86b7-9245-40a3-843e-9ebf0a8251db pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start657_end969_proc.npy
# Skipping 878b86b7-9245-40a3-843e-9ebf0a8251db post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start2842_end3142_proc.npy
# Skipping 878b86b7-9245-40a3-843e-9ebf0a8251db post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start3142_end3500_proc.npy
# Skipping 878b86b7-9245-40a3-843e-9ebf0a8251db post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08457\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start3500_end3812_proc.npy
# Skipping 3e9d9490-7fb2-4aa3-b8cd-83f216ad8cde pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping 3e9d9490-7fb2-4aa3-b8cd-83f216ad8cde pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start300_end656_proc.npy
# Skipping 3e9d9490-7fb2-4aa3-b8cd-83f216ad8cde pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start656_end968_proc.npy
# Skipping 3e9d9490-7fb2-4aa3-b8cd-83f216ad8cde post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start2898_end3198_proc.npy
# Skipping 3e9d9490-7fb2-4aa3-b8cd-83f216ad8cde post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start3198_end3556_proc.npy
# Skipping 3e9d9490-7fb2-4aa3-b8cd-83f216ad8cde post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-11\001\raw_video_data\_iblrig_leftCamera.raw_start3556_end3869_proc.npy
# Skipping 55f3644c-3f86-423e-9beb-6604b5aa4e2c pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping 55f3644c-3f86-423e-9beb-6604b5aa4e2c pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw_start300_end659_proc.npy
# Skipping 55f3644c-3f86-423e-9beb-6604b5aa4e2c pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw_start659_end971_proc.npy
# Skipping 55f3644c-3f86-423e-9beb-6604b5aa4e2c post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw_start3069_end3369_proc.npy
# Skipping 55f3644c-3f86-423e-9beb-6604b5aa4e2c post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw_start3369_end3727_proc.npy
# Skipping 55f3644c-3f86-423e-9beb-6604b5aa4e2c post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08458\2025-03-14\001\raw_video_data\_iblrig_leftCamera.raw_start3727_end4040_proc.npy
# Skipping e8128c55-b322-438a-9498-edd47ae4b794 pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping e8128c55-b322-438a-9498-edd47ae4b794 pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start300_end658_proc.npy
# Skipping e8128c55-b322-438a-9498-edd47ae4b794 pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start658_end970_proc.npy
# Skipping e8128c55-b322-438a-9498-edd47ae4b794 post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start3029_end3329_proc.npy
# Skipping e8128c55-b322-438a-9498-edd47ae4b794 post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start3329_end3687_proc.npy
# Skipping e8128c55-b322-438a-9498-edd47ae4b794 post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start3687_end3999_proc.npy
# Skipping 5c28961e-1183-43f9-86a8-9c1c9d8ed743 pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping 5c28961e-1183-43f9-86a8-9c1c9d8ed743 pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw_start300_end658_proc.npy
# Skipping 5c28961e-1183-43f9-86a8-9c1c9d8ed743 pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw_start658_end970_proc.npy
# Skipping 5c28961e-1183-43f9-86a8-9c1c9d8ed743 post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw_start2822_end3122_proc.npy
# Skipping 5c28961e-1183-43f9-86a8-9c1c9d8ed743 post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw_start3122_end3480_proc.npy
# Skipping 5c28961e-1183-43f9-86a8-9c1c9d8ed743 post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08584\2025-03-19\001\raw_video_data\_iblrig_leftCamera.raw_start3480_end3793_proc.npy
# Skipping bb0e0ad2-4c98-4c98-b92f-559683e8a6f3 pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping bb0e0ad2-4c98-4c98-b92f-559683e8a6f3 pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start300_end658_proc.npy
# Skipping bb0e0ad2-4c98-4c98-b92f-559683e8a6f3 pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start658_end970_proc.npy
# Skipping bb0e0ad2-4c98-4c98-b92f-559683e8a6f3 post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start2943_end3243_proc.npy
# Skipping bb0e0ad2-4c98-4c98-b92f-559683e8a6f3 post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start3243_end3601_proc.npy
# Skipping bb0e0ad2-4c98-4c98-b92f-559683e8a6f3 post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-12\001\raw_video_data\_iblrig_leftCamera.raw_start3601_end3913_proc.npy
# Skipping 58c61f29-d4e6-4ca7-b6de-bd860e83fe4e pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping 58c61f29-d4e6-4ca7-b6de-bd860e83fe4e pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start300_end658_proc.npy
# Skipping 58c61f29-d4e6-4ca7-b6de-bd860e83fe4e pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start658_end971_proc.npy
# Skipping 58c61f29-d4e6-4ca7-b6de-bd860e83fe4e post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start2830_end3130_proc.npy
# Skipping 58c61f29-d4e6-4ca7-b6de-bd860e83fe4e post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start3130_end3491_proc.npy
# Skipping 58c61f29-d4e6-4ca7-b6de-bd860e83fe4e post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-18\001\raw_video_data\_iblrig_leftCamera.raw_start3491_end3803_proc.npy
# Skipping cdc1965e-4324-422a-a9d4-86b4e5d0de92 pre_task00_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw_start0_end300_proc.npy
# Skipping cdc1965e-4324-422a-a9d4-86b4e5d0de92 pre_task00_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw_start300_end656_proc.npy
# Skipping cdc1965e-4324-422a-a9d4-86b4e5d0de92 pre_task00_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw_start656_end969_proc.npy
# Skipping cdc1965e-4324-422a-a9d4-86b4e5d0de92 post_task01_spontaneous: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw_start2840_end3140_proc.npy
# Skipping cdc1965e-4324-422a-a9d4-86b4e5d0de92 post_task01_rfm: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw_start3140_end3499_proc.npy
# Skipping cdc1965e-4324-422a-a9d4-86b4e5d0de92 post_task01_replay: already processed at C:\Users\marti\Downloads\ONE\alyx.internationalbrainlab.org\mainenlab\Subjects\ZFM-08631\2025-03-21\001\raw_video_data\_iblrig_leftCamera.raw_start3499_end3812_proc.npy

# %%
results_df = pd.DataFrame(results)
results_df.columns = ["eid", "epoch", "savename"]

results_df.to_csv('cont_results', index=False)
